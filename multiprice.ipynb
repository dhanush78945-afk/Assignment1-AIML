# %% [markdown]
# <a href="https://colab.research.google.com/github/dhanush78945-afk/Assignment1-AIML/blob/main/multiprice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub
path = kagglehub.dataset_download("kanchana1990/colorado-real-estate-market-2026")
# Out:
# ...
# 100%|██████████| 3.13M/3.13M [00:00<00:00, 49.1MB/s]
# Extracting files...

# %%
import os
import pandas as pd

# List the contents of the downloaded path
print(os.listdir(path))
# Out:
# ['colorado_real_estate_2026.csv']

# %%
# Assuming the CSV file is named 'Colorado_Real_Estate_Data.csv' based on typical Kaggle dataset structures.
# If the file name is different, this cell will need to be adjusted.
df = pd.read_csv(os.path.join(path, 'colorado_real_estate_2026.csv'))

# Display the first 5 rows of the DataFrame
display(df.head())
# Out:
#             type   sub_type  \
# 0  single_family        NaN
# 1  single_family        NaN
# 2  single_family        NaN
# 3         condos      condo
# 4      townhomes  townhouse
#
#                                                 text  listPrice    sqft  \
# 0  Beautifully maintained and spacious brick ranc...     479000  2492.0
# 1  $150, 000 PRICE CUT! And it still comes with a...     425000  3140.0
# 2  Located on a quiet cul-de-sac in the desirable...     390000  2132.0
# 3  3 bedroom, 3 bathroom Aspen Hills condo. LIST ...     100000  1328.0
# 4  Welcome to this beautiful townhome in Ridgevie...     375000  1615.0
#
#    stories  beds  baths  baths_full  baths_full_calc  garage
# 0      1.0   4.0    3.0         1.0              2.0     2.0
# 1      3.0   4.0    5.0         4.0              4.0     1.0
# 2      1.0   4.0    2.0         2.0              2.0     2.0
# 3      2.0   3.0    3.0         2.0              2.0     1.0
# ...

# %%
# Display information about the DataFrame, including column data types and non-null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8362 entries, 0 to 8361
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   type             8362 non-null   object
#  1   sub_type         1564 non-null   object
#  2   text             8323 non-null   object
#  3   listPrice        8362 non-null   int64
#  4   sqft             5977 non-null   float64
#  5   stories          4544 non-null   float64
#  6   beds             5998 non-null   float64
#  7   baths            7082 non-null   float64
#  8   baths_full       5768 non-null   float64
#  9   baths_full_calc  5969 non-null   float64
#  10  garage           4543 non-null   float64
# dtypes: float64(7), int64(1), object(3)
# memory usage: 718.7+ KB
